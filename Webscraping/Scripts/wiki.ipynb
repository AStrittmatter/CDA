# %% [markdown]
# #  Wikipedia examples

# %% [markdown]
# ## Requirements

# %%
## install and load required library
## install.packages("rvest", dependencies = TRUE)
library(rvest)

# %% [markdown]
# ## Scraping a wiki table

# %%
## 1) fetch and parse the website
page <- read_html("https://en.wikipedia.org/wiki/Infant_mortality")
## 2) extract the html node containing the table
table <- html_node(page, xpath = "//*[@id='mw-content-text']/div/table[2]")
## 3) extract the table as a data frame
mrates <- html_table(table)
mrates
# Out:
#    Rank Country
# 1    1  Afghanistan
# 2    2  Niger
# 3    3  Mali
# 4    4  Somalia
# 5    5  Central African Republic
# 6  218  Sweden
# 7  219  Singapore
# 8  220  Bermuda
# 9  221  Japan
# 10 222  Monaco
#    Infant mortality rate  (deaths/1,000 live births)
# 1  121.63
# 2  109.98
# 3  109.08
# 4  103.72
# 5   97.17
# 6    2.74
# 7    2.65
# 8    2.47
# 9    2.21
# 10   1.80

# %% [markdown]
# ## Investigating page elements and navigation

# %%
## using css or xpath selectors is equivalent
## table <- html_node(page, xpath = "//*[@id='mw-content-text']/div/table[2]")
table <- html_node(page, css = "#mw-content-text > div > table:nth-child(121)")
mrates <- html_table(table)
mrates
# Out:
#    Rank Country
# 1    1  Afghanistan
# 2    2  Niger
# 3    3  Mali
# 4    4  Somalia
# 5    5  Central African Republic
# 6  218  Sweden
# 7  219  Singapore
# 8  220  Bermuda
# 9  221  Japan
# 10 222  Monaco
#    Infant mortality rate  (deaths/1,000 live births)
# 1  121.63
# 2  109.98
# 3  109.08
# 4  103.72
# 5   97.17
# 6    2.74
# 7    2.65
# 8    2.47
# 9    2.21
# 10   1.80

# %%
## list table nodes
html_nodes(page, "table")
# Out:
# {xml_nodeset (10)}
#  [1] <table class="wikitable" style="float:right; margin: 0.5em 0 0.5em 1em;  ...
#  [2] <table class="wikitable" style="text-align:left"><tbody>\n<tr>\n<th>Rank ...
#  [3] <table role="presentation" class="mbox-small plainlinks sistersitebox" s ...
#  [4] <table class="nowraplinks hlist collapsible collapsed navbox-inner" styl ...
#  [5] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbo ...
#  [6] <table class="nowraplinks collapsible autocollapse navbox-inner" style=" ...
#  [7] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbo ...
#  [8] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbo ...
#  [9] <table class="nowraplinks hlist collapsible autocollapse navbox-inner" s ...
# [10] <table class="nowraplinks navbox-subgroup" style="border-spacing:0"><tbo ...

# %%
## check out links in the table
html_nodes(table, "a") %>% html_attr("href")
tablelinks <- html_attr(html_nodes(table, "a"), "href")
link <- grep("Somalia", tablelinks, value = TRUE)
link
# Out:
#  [1] "/wiki/Afghanistan"              "/wiki/Niger"
#  [3] "/wiki/Mali"                     "/wiki/Somalia"
#  [5] "/wiki/Central_African_Republic" "/wiki/Sweden"
#  [7] "/wiki/Singapore"                "/wiki/Bermuda"
#  [9] "/wiki/Japan"                    "/wiki/Monaco"
# [1] "/wiki/Somalia"

# %%
## looking at html elements and their attributes
# html_nodes(page, "link")
# html_nodes(page, "a") %>% html_attr("href")
html_nodes(page, "a")
html_attr(html_nodes(table, "a"), "href")
# Out:
# {xml_nodeset (1661)}
#  [1] <a id="top"></a>
#  [2] <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
#  [3] <a class="mw-jump-link" href="#p-search">Jump to search</a>
#  [4] <a href="/wiki/File:Infant_mortality_map_of_the_world.svg" class="image" ...
#  [5] <a href="/wiki/File:Infant_mortality_map_of_the_world.svg" class="intern ...
#  [6] <a href="#cite_note-1">[1]</a>
#  [7] <a href="#cite_note-2">[2]</a>
#  [8] <a href="#cite_note-3">[3]</a>
#  [9] <a href="/wiki/Neonatal_infection" title="Neonatal infection">neonatal i ...
# [10] <a href="#cite_note-4">[4]</a>
# [11] <a href="#cite_note-pmid27467563-5">[5]</a>
# [12] <a href="#cite_note-pmid26195213-6">[6]</a>
# [13] <a href="/wiki/Sanitation" title="Sanitation">sanitation</a>
# [14] <a href="/wiki/Immunization" title="Immunization">immunization</a>
# [15] <a href="/wiki/Infectious_diseases" class="mw-redirect" title="Infectiou ...
# [16] <a href="/wiki/Public_health" title="Public health">public health</a>
# [17] <a href="/wiki/Child_mortality" title="Child mortality">Child mortality</a>
# [18] <a href="#cite_note-7">[7]</a>
# [19] <a href="/wiki/Millennium_Development_Goals" title="Millennium Developme ...
# [20] <a href="/wiki/United_Nations" title="United Nations">United Nations</a>
# ...
#  [1] "/wiki/Afghanistan"              "/wiki/Niger"
#  [3] "/wiki/Mali"                     "/wiki/Somalia"
#  [5] "/wiki/Central_African_Republic" "/wiki/Sweden"
#  [7] "/wiki/Singapore"                "/wiki/Bermuda"
#  [9] "/wiki/Japan"                    "/wiki/Monaco"

# %%
## follwing a link to another page, fetching another table
session <- html_session("https://en.wikipedia.org/wiki/Infant_mortality")
session <- follow_link(session, "Somalia")
page <- read_html(session)
table <- html_node(page, xpath = "//*[@id='mw-content-text']/div/table[4]")
regions <- html_table(table)
regions
# Out:
# Navigating to /wiki/Somalia
#    Region          Area (km2) Population Capital
# 1  Awdal           21,374     673,263    Borama
# 2  Woqooyi Galbeed 28,836     1,242,003  Hargeisa
# 3  Togdheer        38,663     721,363    Burao
# 4  Sanaag          53,374     544,123    Erigavo
# 5  Sool            25,036     327,428    Las Anod
# 6  Bari            70,088     719,512    Bosaso
# 7  Nugal           26,180     392,697    Garowe
# 8  Mudug           72,933     717,863    Galkayo
# 9  Galguduud       46,126     569,434    Dusmareb
# 10 Hiran           31,510     520,685    Beledweyne
# 11 Middle Shabelle 22,663     516,036    Jowhar
# 12 Banaadir        370        1,650,227  Mogadishu
# 13 Lower Shabelle  25,285     1,202,219  Barawa
# 14 Bakool          26,962     367,226    Xuddur
# 15 Bay             35,156     792,182    Baidoa
# 16 Gedo            60,389     508,405    Garbahaarreey
# 17 Middle Juba     9,836      362,921    Bu'aale
# 18 Lower Juba      42,876     489,307    Kismayo

# %% [markdown]
# ## Regex filtering

# %%
## filtering links
page <- read_html("https://en.wikipedia.org/wiki/Infant_mortality")
wikilinks <- html_attr(html_nodes(page, "a"), "href")
wikilinks
# Out:
#    [1] NA
#    [2] "#mw-head"
#    [3] "#p-search"
#    [4] "/wiki/File:Infant_mortality_map_of_the_world.svg"
#    [5] "/wiki/File:Infant_mortality_map_of_the_world.svg"
#    [6] "#cite_note-1"
#    [7] "#cite_note-2"
#    [8] "#cite_note-3"
#    [9] "/wiki/Neonatal_infection"
#   [10] "#cite_note-4"
#   [11] "#cite_note-pmid27467563-5"
#   [12] "#cite_note-pmid26195213-6"
#   [13] "/wiki/Sanitation"
#   [14] "/wiki/Immunization"
#   [15] "/wiki/Infectious_diseases"
#   [16] "/wiki/Public_health"
#   [17] "/wiki/Child_mortality"
#   [18] "#cite_note-7"
#   [19] "/wiki/Millennium_Development_Goals"
#   [20] "/wiki/United_Nations"
#   [21] "/wiki/Sustainable_Development_Goals"
#   [22] "#cite_note-SDG-8"
#   [23] "#cite_note-9"
#   [24] "#Classification"
#   [25] "#Causes"
#   [26] "#Medical"
#   [27] "#Congenital_malformations"
#   [28] "#Low_birth_weight"
#   [29] "#Sudden_infant_death_syndrome"
#   [30] "#Malnutrition"
#   [31] "#Adverse_effects_of_malnutrition"
#   [32] "#Infectious_diseases"
#   [33] "#Environmental"
#   [34] "#Early_childhood_trauma"
#   [35] "#Socio-economic_factors"
#   [36] "#War"
#   [37] "#Medicine_and_biology"
#   [38] "#Economics"
#   [39] "#Cultural"
#   [40] "#Gender_favoritism"
#   [41] "#Birth_spacing"
#   [42] "#Prevention_and_outcomes"
#   [43] "#Public_health"
#   [44] "#Medical_treatments"
#   [45] "#Education"
#   [46] "#Income"
#   [47] "#Policies"
#   [48] "#Differences_in_measurement"
#   [49] "#Europe_and_America"
#   [50] "#Russia"
#   [51] "#Brazil"
#   [52] "#Epidemiology"
#   [53] "#United_States"
#   [54] "#African_American"
#   [55] "#History"
#   [56] "#United_States_2"
#   [57] "#China"
#   [58] "#See_also"
#   [59] "#References"
#   [60] "#External_links"
#   [61] "/w/index.php?title=Infant_mortality&action=edit&section=1"
#   [62] "#cite_note-Andrews-10"
#   [63] "/wiki/Perinatal_mortality"
#   [64] "#cite_note-Andrews-10"
#   [65] "/wiki/Neonatal_mortality"
#   [66] "#cite_note-Norton-11"
#   [67] "#cite_note-12"
#   [68] "/w/index.php?title=Infant_mortality&action=edit&section=2"
#   [69] "#cite_note-13"
#   [70] "/wiki/Infections"
#   [71] "/wiki/Premature_births"
#   [72] "/wiki/Asphyxia"
#   [73] "#cite_note-Andrews-10"
#   [74] "#cite_note-Bishai-14"
#   [75] "#cite_note-Osel2008-15"
#   [76] "/w/index.php?title=Infant_mortality&action=edit&section=3"
#   [77] "/wiki/Sudden_infant_death_syndrome"
#   [78] "/wiki/Neglected_tropical_diseases"
#   [79] "/w/index.php?title=Infant_mortality&action=edit&section=4"
#   [80] "#cite_note-16"
#   [81] "#cite_note-pmid10942444-17"
#   [82] "#cite_note-pmid22078432-18"
#   [83] "/w/index.php?title=Infant_mortality&action=edit&section=5"
#   [84] "/wiki/Low_birth_weight"
#   [85] "/wiki/Low_birth_weight"
#   [86] "/wiki/The_New_England_Journal_of_Medicine"
#   [87] "/wiki/Prenatal_care"
#   [88] "#cite_note-Andrews-10"
#   [89] "#cite_note-MacDorman_2009-19"
#   [90] "#cite_note-20"
#   [91] "#cite_note-21"
#   [92] "/wiki/Teenage_pregnancy"
#   [93] "#cite_note-lag-22"
#   [94] "/w/index.php?title=Infant_mortality&action=edit&section=6"
#   [95] "/wiki/Sudden_infant_death_syndrome"
#   [96] "#cite_note-Duncan_2018-23"
#   [97] "#cite_note-pmid8165085-24"
#   [98] "#cite_note-Duncan_2018-23"
#   [99] "/w/index.php?title=Infant_mortality&action=edit&section=7"
#  [100] "/wiki/Malnutrition_in_children"
#  [101] "#cite_note-25"
#  [102] "#cite_note-26"
#  [103] "#cite_note-27"
#  [104] "#cite_note-28"
#  [105] "/w/index.php?title=Infant_mortality&action=edit&section=8"
#  [106] "#cite_note-:1-29"
#  [107] "#cite_note-:02-30"
#  [108] "#cite_note-:02-30"
#  [109] "#cite_note-:1-29"
#  [110] "#cite_note-:1-29"
#  [111] "#cite_note-31"
#  [112] "/w/index.php?title=Infant_mortality&action=edit&section=9"
#  [113] "/wiki/Pelvic_inflammatory_disease"
#  [114] "/wiki/Sexually_transmitted_disease"
#  [115] "#cite_note-pmid23976885-32"
#  [116] "/wiki/Acute_respiratory_infection"
#  [117] "/wiki/Diarrhea"
#  [118] "/wiki/Measles"
#  [119] "/wiki/Malaria"
#  [120] "/wiki/Pneumonia"
#  [121] "/wiki/Bronchitis"
#  [122] "/wiki/Bronchiolitis"
#  [123] "#cite_note-Andrews-10"
#  [124] "#cite_note-Nussbaum-33"
#  [125] "/wiki/Folic_acid"
#  [126] "/wiki/Public_health"
#  [127] "#cite_note-Andrews-10"
#  [128] "/wiki/Anemia"
#  [129] "#cite_note-34"
#  [130] "/w/index.php?title=Infant_mortality&action=edit&section=10"
#  [131] "#cite_note-MacDorman_2009-19"
#  [132] "#cite_note-Gortmaker_1997-35"
#  [133] "#cite_note-Gortmaker_1997-35"
#  [134] "/wiki/Water_pollution"
#  [135] "/wiki/Pathogens"
#  [136] "/wiki/Parasitic"
#  [137] "/wiki/Microbial"
#  [138] "#cite_note-Jorgenson-36"
#  [139] "/wiki/Socioeconomic_status"
#  [140] "#cite_note-Andrews-10"
#  [141] "#cite_note-Andrews-10"
#  [142] "#cite_note-Jorgenson-36"
#  [143] "/wiki/Particulate_matter"
#  [144] "#cite_note-37"
#  [145] "#cite_note-Glinianaia-38"
#  [146] "#cite_note-39"
#  [147] "/wiki/Carbon_monoxide"
#  [148] "#cite_note-40"
#  [149] "/wiki/Institutionalized_racism"
#  [150] "#cite_note-Osel2008-15"
#  [151] "#cite_note-41"
#  [152] "/w/index.php?title=Infant_mortality&action=edit&section=11"
#  [153] "/wiki/Early_childhood_trauma"
#  [154] "/wiki/Childhood_trauma"
#  [155] "#cite_note-childwelfare.gov_fatality-42"
#  [156] "#cite_note-pmid24094272-43"
#  [157] "#cite_note-childwelfare.gov_fatality-42"
#  [158] "#cite_note-pmid23018311-44"
#  [159] "#cite_note-pmid24402794-45"
#  [160] "#cite_note-46"
#  [161] "/wiki/Poverty"
#  [162] "/wiki/Adverse_Childhood_Experiences_Study"
#  [163] "#cite_note-47"
#  [164] "#cite_note-childwelfare.gov_fatality-42"
#  [165] "/w/index.php?title=Infant_mortality&action=edit&section=12"
#  [166] "/wiki/Social_class"
#  [167] "/wiki/Income"
#  [168] "/wiki/Correlation"
#  [169] "/wiki/Race_(classification_of_humans)"
#  [170] "#cite_note-ReferenceA-48"
#  [171] "#cite_note-Osel2008-15"
#  [172] "/wiki/The_Economist"
#  [173] "#cite_note-49"
#  [174] "#cite_note-50"
#  [175] "/wiki/Socioeconomic"
#  [176] "/wiki/Technology"
#  [177] "#cite_note-Gortmaker_1997-35"
en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License"
# [1649] "//creativecommons.org/licenses/by-sa/3.0/"
# [1650] "//foundation.wikimedia.org/wiki/Terms_of_Use"
# [1651] "//foundation.wikimedia.org/wiki/Privacy_policy"
# [1652] "//www.wikimediafoundation.org/"
# [1653] "https://foundation.wikimedia.org/wiki/Privacy_policy"
# [1654] "/wiki/Wikipedia:About"
# [1655] "/wiki/Wikipedia:General_disclaimer"
# [1656] "//en.wikipedia.org/wiki/Wikipedia:Contact_us"
# [1657] "https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute"
# [1658] "https://foundation.wikimedia.org/wiki/Cookie_statement"
# [1659] "//en.m.wikipedia.org/w/index.php?title=Infant_mortality&mobileaction=toggle_view_mobile"
# [1660] "https://wikimediafoundation.org/"
# [1661] "//www.mediawiki.org/"

# %%
## regex examples
links <- grep("^/wiki", wikilinks, value = TRUE)
links <- grep("^/wiki.*[0-9][0-9]$", wikilinks, value = TRUE)
links <- grep("^/wiki.*File:.*", wikilinks, value = TRUE)
links <- grep("^(?!.*:)/wiki/.*Mortality", wikilinks, value = TRUE, perl = TRUE)
links <- grep("^(?!.*:)(/wiki/.*Mortality)|(/wiki/.*Somalia)", wikilinks, value = TRUE, perl = TRUE)
links
# Out:
# [1] "/wiki/Somalia"                "/wiki/Mortality_displacement"
# [3] "/wiki/Mortality_rate"         "/wiki/Mortality_salience"

# %%
# sometimes easier to do it in multiple steps for readability
links <- grep("^/wiki/", wikilinks, value = TRUE)
links <- grep("Mortality|Somalia", links, value = TRUE)
links <- grep(":", links, value = TRUE, invert = TRUE)
links
# Out:
# [1] "/wiki/Somalia"                "/wiki/Mortality_displacement"
# [3] "/wiki/Mortality_rate"         "/wiki/Mortality_salience"

# %%
# select only internal links matching with mortality or somalia, no files or category pages
links <- grep("^(?!.*:)(/wiki/.*Mortality)|(/wiki/.*Somalia)", wikilinks,
              ignore.case = TRUE, value = TRUE, perl = TRUE)
links <- unique(links)
links
# Out:
#  [1] "/wiki/Child_mortality"
#  [2] "/wiki/Perinatal_mortality"
#  [3] "/wiki/Neonatal_mortality"
#  [4] "/wiki/List_of_countries_by_infant_mortality_rate"
#  [5] "/wiki/Somalia"
#  [6] "/wiki/Gompertz%E2%80%93Makeham_law_of_mortality"
#  [7] "/wiki/Immortality"
#  [8] "/wiki/Biological_immortality"
#  [9] "/wiki/Digital_immortality"
# [10] "/wiki/Maternal_mortality_in_fiction"
# [11] "/wiki/Mortality_displacement"
# [12] "/wiki/Mortality_rate"
# [13] "/wiki/Risk_adjusted_mortality_rate"
# [14] "/wiki/Mortality_salience"
# [15] "/wiki/Infant_mortality"

# %%
# navigate to linked page
session <- jump_to(session, links[1])
page <- read_html(session)
html_nodes(page, "title")
# Out:
# {xml_nodeset (1)}
# [1] <title>Child mortality - Wikipedia</title>\n

# %%
# navigate to linked page
session <- jump_to(session, links[5])
page <- read_html(session)
html_nodes(page, "title")
# Out:
# {xml_nodeset (1)}
# [1] <title>Somalia - Wikipedia</title>\n
